# %%
import boto3
import re
import os
import json
import time
import base64

# %%
# establish clients
batch_client = boto3.client('batch')
ec2_client = boto3.client("ec2")
batch_client = boto3.client("batch")

# setup keypair for instance access
ec2KeyPair = "phoenixlogan"

# %%
# set up aws resource names
launch_template = "phoenixlogan-template-ska-2"
compute_environment = "phoenixlogan-compute"
job_queue = "phoenixlogan-queue"
job_definition = "phoenixlogan-ska-def-2"

# setup compute environment parameters 
root_volume_size = 2000
instance_types = ["optimal"]

# setup batch job parameters
job_image = 'phoenixajalogan/kmer-ska-batch'
job_vcpus = 15
job_memory = 40000
# Out:
# Creating job definition...
# Finished creating job definition.

# %%
print("Creating launch template...")
with open("logs/launch_template.json", "w") as f:
    json.dump(
        ec2_client.create_launch_template(
            LaunchTemplateName=launch_template,
            LaunchTemplateData={
                "BlockDeviceMappings": [
                    {
                        "DeviceName": "/dev/xvda",
                        "Ebs": {
                            "DeleteOnTermination": True,
                            "VolumeSize": root_volume_size,
                            "VolumeType": "gp2"
                        }
                    }
                ],
            }
        ),
        f, default=str, indent=4
    )
print("Finished creating launch template.")

# %%
print("Creating compute environment...")
with open("logs/compute_environment.json", "w") as f:
    compute_resources = {
        'type': 'EC2',
        'minvCpus': 0,
        'maxvCpus': 256,
        'instanceTypes': instance_types,
        'subnets': [
            # subnets for us-west-2a, us-west-2b, us-west-2c
            "subnet-672e832e",
            "subnet-04119a63",
            "subnet-4347451b",
        ],
        'securityGroupIds': [
            'sg-3195a049',
        ],
        "ec2KeyPair": ec2KeyPair,
        'instanceRole': 'ecsInstanceRole2',
        'bidPercentage': 100,
        'spotIamFleetRole': 'arn:aws:iam::423543210473:role/aws-ec2-spot-fleet-role',
        'launchTemplate': {
            'launchTemplateName': launch_template
        }
    }
    json.dump(
        batch_client.create_compute_environment(
            computeEnvironmentName=compute_environment,
            type='MANAGED',
            state='ENABLED',
            computeResources=compute_resources,
            serviceRole='arn:aws:iam::423543210473:role/AWSBatchServiceRole'
        ),
        f, default=str, indent=4
    )
print("Finished creating compute environment.")

# %%
print("Creating job queue...")
n_tries = 5
sleep_time = 30
for i in range(n_tries):
    desc, = batch_client.describe_compute_environments(
        computeEnvironments=[compute_environment]
    )["computeEnvironments"]
    if desc['status'] != 'VALID':
        print("Waiting for compute environment...",
              f"(Try {i+1}/{n_tries})")
        time.sleep(sleep_time)
    else:
        break
with open("logs/job_queue.json", "w") as f:
    json.dump(
        batch_client.create_job_queue(
            jobQueueName=job_queue,
            state='ENABLED',
            priority=5,
            computeEnvironmentOrder=[
                {
                    'order': 5,
                    'computeEnvironment': compute_environment
                },
            ]
        ),
        f, default=str, indent=4
    )
print("Finished creating job queue.")

# %%
print("Creating job definition...")
with open("logs/job_definition.json", "w") as f:
    json.dump(
        batch_client.register_job_definition(
            jobDefinitionName="ska-sketch",
            type='container',
            containerProperties={
                "image": job_image,
                "vcpus": job_vcpus,
                "memory": job_memory,
                "command": [
                    "prep_files.py",
                    "Ref::bucket_name",
                    "Ref::key1",
                    "Ref::key2",
                    "Ref::size",
                    "Ref::outbucket"
                ],
                "volumes": [
                    {"host": {"sourcePath": "/scratch"},
                     "name": "scratch"},
                ],
                "mountPoints": [
                    {"containerPath": "/scratch",
                     "sourceVolume": "scratch"},
                ],
                "jobRoleArn": "arn:aws:iam::423543210473:role/simpleBatchJob",
                "privileged": True
            }
        ),
        f, default=str, indent=4
    )
print("Finished creating job definition.")

# %%
# download fastq files from S3
s3_resource = boto3.resource("s3")

seq_bucket_name = "czbiohub-mosquito"
seq_bucket_prefixes = ["sequences/CMS001_fastq.gz", "sequences/CMS002_fastq.gz"]
first_reads = re.compile(r".+(R1).+")

sample_names = []
seq_bucket = s3_resource.Bucket(seq_bucket_name)
for obj in seq_bucket.objects.filter(Prefix=seq_bucket_prefixes[0]):
    matched = first_reads.match(os.path.basename(obj.key))
    if matched:
        sample_names.append(matched.group(0))

# %%
# load compute and queue arns to map to job submission
with open("logs/job_definition.json") as f:
    jobDefinition = json.load(f)["jobDefinitionArn"]

with open("logs/job_queue.json") as f:
    jobQueue = json.load(f)["jobQueueArn"]
    
# submit batch jobs 
for sample in sample_names[3:]:
    s3_fq = f"s3://{seq_bucket_name}/{seq_bucket_prefixes[1]}/{sample}"
    response = batch_client.submit_job(
        jobName=sample.replace(".fastq.gz", ""),
        jobQueue=jobQueue,
        jobDefinition=jobDefinition,
        parameters={
            "bucket_name": seq_bucket_name,
            "key1": s3_fq,
            "key2": s3_fq.replace("R1", "R2"),
            "size": "30000",
            "outbucket": "phoenixlogan-ska-sketches"
        }
    )
    prefix = sample.replace(".fastq.gz", "")
    with open(f"logs/jobs/{prefix}.json", "w") as f:
        json.dump(response, f, indent=4, default=str)
# Out:
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_004_RNA_A_S2_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_005_RNA_A_S3_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_006_RNA_A_S5_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_007_RNA_A_S12_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_008_RNA_A_S3_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_009_RNA_A_S13_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_010_RNA_A_S1_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_011_RNA_A_S4_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_012_RNA_A_S4_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_013_RNA_A_S5_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_014_RNA_A_S5_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_015_RNA_A_S13_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_016_RNA_A_S6_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_017_RNA_A_S6_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_018_RNA_A_S14_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_019_RNA_A_S14_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_020_RNA_A_S15_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_021_RNA_A_S16_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_022_RNA_A_S6_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_023_RNA_A_S17_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_024_RNA_A_S15_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_025_RNA_A_S7_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_026_RNA_A_S18_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_027_RNA_A_S16_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_028_RNA_A_S17_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_029_RNA_A_S18_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_030_RNA_A_S7_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_031_RNA_A_S19_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_032_RNA_A_S7_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_033_RNA_A_S8_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_034_RNA_A_S19_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_035_RNA_A_S20_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_036_RNA_A_S20_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_037_RNA_A_S21_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_038_RNA_A_S22_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_039_RNA_A_S9_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_040_RNA_A_S21_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_041_RNA_A_S10_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_042_RNA_A_S23_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_043_RNA_A_S24_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_044_RNA_A_S25_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_045_RNA_A_S2_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_046_RNA_A_S3_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_047_RNA_A_S4_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_048_RNA_A_S5_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_049_RNA_A_S6_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_050_RNA_A_S23_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_051_RNA_A_S8_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_052_RNA_A_S7_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_053_RNA_A_S8_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_054_RNA_A_S11_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_055_RNA_A_S9_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_056_RNA_A_S10_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_057_RNA_A_S11_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_058_RNA_A_S9_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_059_RNA_A_S10_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_060_RNA_A_S12_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_water1_S11_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_water2_S24_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_water3_Qiagen_S26_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_water4_Zymo_S27_R1_001.fastq.gz
# s3://czbiohub-mosquito/sequences/CMS002_fastq.gz/CMS_water5_RNA_A_S12_R1_001.fastq.gz
