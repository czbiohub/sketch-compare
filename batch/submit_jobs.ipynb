# %%
import boto3
import re
import os
import json
import time
import base64
from botocore.exceptions import ClientError

# %%
batch_client = boto3.client('batch')
job_image = 'phoenixajalogan/kmer-ska-batch'
ec2_client = boto3.client("ec2")

# setup keypair for instance access
ec2KeyPair = "phoenixlogan"

# set up aws resource names
launch_template = "phoenixlogan-template-ska"
compute_environment = "phoenixlogan-compute"
job_queue = "phoenixlogan-queue"
job_definition = "phoenixlogan-ska-def"

# setup compute environment parameters 
root_volume_size = 2000
instance_types = ["optimal"]

# setup batch job parameters
job_vcpus = 15
job_memory = 40000

# %%
try:
    print("Creating launch template...")
    with open("logs/launch_template.json", "w") as f:
        json.dump(
            ec2_client.create_launch_template(
                LaunchTemplateName=launch_template,
                LaunchTemplateData={
                    "BlockDeviceMappings": [
                        {
                            "DeviceName": "/dev/xvda",
                            "Ebs": {
                                "DeleteOnTermination": True,
                                "VolumeSize": root_volume_size,
                                "VolumeType": "gp2"
                            }
                        }
                    ],
                }
            ),
            f, default=str, indent=4
        )
    print("Finished creating launch template.")
except ClientError as e:
    print(e.response["Error"]["Message"])
    pass
# Out:
# Creating launch template...
# Launch template name already in use.

# %%
try:
    print("Creating compute environment...")
    with open("logs/compute_environment.json", "w") as f:
        compute_resources = {
            'type': 'EC2',
            'minvCpus': 0,
            'maxvCpus': 256,
            'instanceTypes': instance_types,
            'subnets': [
                # subnets for us-west-2a, us-west-2b, us-west-2c\n",
                "subnet-672e832e",
                "subnet-04119a63",
                "subnet-4347451b",
            ],
            'securityGroupIds': [
                'sg-3195a049',
            ],
            "ec2KeyPair": ec2KeyPair,
            'instanceRole': 'ecsInstanceRole2',
            'bidPercentage': 100,
            'spotIamFleetRole': 'arn:aws:iam::423543210473:role/aws-ec2-spot-fleet-role',
            'launchTemplate': {
                'launchTemplateName': launch_template
            }
        }
        json.dump(
            batch_client.create_compute_environment(
                computeEnvironmentName=compute_environment,
                type='MANAGED',
                state='ENABLED',
                computeResources=compute_resources,
                serviceRole='arn:aws:iam::423543210473:role/AWSBatchServiceRole'
            ),
            f, default=str, indent=4
        )
    print("Finished creating compute environment.")
    
except ClientError as e:
    print(e.response["Error"]["Message"])
    pass
# Out:
# Creating compute environment...
# Object already exists

# %%
try:
    print("Creating job queue...")
    n_tries = 5
    sleep_time = 30
    for i in range(n_tries):
        desc, = batch_client.describe_compute_environments(
            computeEnvironments=[compute_environment]
        )["computeEnvironments"]
        if desc['status'] != 'VALID':
            print("Waiting for compute environment...",
                  f"(Try {i+1}/{n_tries})")
            time.sleep(sleep_time)
        else:
            break
    with open("logs/job_queue.json", "w") as f:
        json.dump(
            batch_client.create_job_queue(
                jobQueueName=job_queue,
                state='ENABLED',
                priority=5,
                computeEnvironmentOrder=[
                    {
                        'order': 5,
                        'computeEnvironment': compute_environment
                    },
                ]
            ),
            f, default=str, indent=4
        )
    print("Finished creating job queue.")

except ClientError as e:
    print(e.response["Error"]["Message"])
    pass

# %%
print("Creating job definition...")
with open("logs/job_definition.json", "w") as f:
    json.dump(
        batch_client.register_job_definition(
            jobDefinitionName=job_definition,
            type='container',
            containerProperties={
                "image": job_image,
                "vcpus": job_vcpus,
                "memory": job_memory,
                "command": [
                    "create_sketch.py",
                    "Ref::bucket_name",
                    "Ref::key1",
                    "Ref::key2",
                    "Ref::size",
                    "Ref::ksize",
                    "Ref::outbucket",
                ],
                "volumes": [
                    {"host": {"sourcePath": "/scratch"},
                     "name": "scratch"},
                ],
                "mountPoints": [
                    {"containerPath": "/scratch",
                     "sourceVolume": "scratch"},
                ],
                "jobRoleArn": "arn:aws:iam::423543210473:role/simpleBatchJob",
                "privileged": True
            }
        ),
        f, default=str, indent=4
    )
print("Finished creating job definition.")
# Out:
# Creating job definition...
# Finished creating job definition.

# %%
def files_list(keys, bucket_name):
    """
    Args:
        keys (lst): file prefixes to pass .

    Returns:
        list : all sample names to pass to batch
    
    """
    
    # download fastq files from S3
    s3_resource = boto3.resource("s3")
    #seq_bucket_name = "czbiohub-mosquito"
    seq_bucket_name = bucket_name
    first_reads = re.compile(r".+(R1).+")
    
    sample_names = []
    
    for key in keys:
        print(key)
        seq_bucket = s3_resource.Bucket(seq_bucket_name)
        for obj in seq_bucket.objects.filter(Prefix=key):
            matched = first_reads.match(os.path.basename(obj.key))
            if matched:
                sample_names.append(matched.group(0))
                
    return sample_names[0:75]

# %%
# load compute and queue arns to map to job submission
with open("logs/job_definition.json") as f:
    jobDefinition = json.load(f)["jobDefinitionArn"]

with open("logs/job_queue.json") as f:
#     jobQueue = json.load(f)["jobQueueArn"]
    jobQueue = "arn:aws:batch:us-west-2:423543210473:job-queue/phoenixlogan-queue"

seq_buckets = {
    "sequences/CMS001_fastq.gz": files_list(["sequences/CMS001_fastq.gz"], "czbiohub-mosquito"), 
    "sequences/CMS002_fastq.gz": files_list(["sequences/CMS002_fastq.gz"], "czbiohub-mosquito")
}

all_file_paths = []

for k in seq_buckets.keys():
    val = seq_buckets[k]
    for v in val:
        path = os.path.join(k, v)
#         print(f"PATH: {path}")
        all_file_paths.append(path)
all_file_paths
# Out:
# sequences/CMS001_fastq.gz
# sequences/CMS002_fastq.gz

# %%
# s3 = boto3.resource("s3")
# maca_bucket = s3.Bucket(name='czb-maca')
# maca_files = [fp.key for fp in maca_bucket.objects.filter(Prefix='Plate_seq/3_month/170907_A00111_0051_BH2HWLDMXX')]
# maca_files[0:50]
# seq_buckets = {
#     "Plate_seq/3_month/170907_A00111_0051_BH2HWLDMXX/fastqs": files_list(["Plate_seq/3_month/170907_A00111_0051_BH2HWLDMXX/fastqs"], "czb-maca"), 
# }
# seq_buckets

# %%
import pandas as pd

path_locations = pd.read_csv("metadata_formatted.csv")
path_locations.head()
fps = [x.replace("s3://czb-seqbot/", "") for x in list(path_locations["read1"])]
ids = list(path_locations["id"])
ids_and_fps = zip(ids, fps)

# %%
# submit batch jobs 

seq_bucket_name = "czb-seqbot"

for i, fp in ids_and_fps:
    sample = i
    size = "10000000_seqbot"
    identifier = f"{sample}_{size}"
    print(identifier)
    response = batch_client.submit_job(
        jobName=identifier,
        jobQueue=job_queue,
        jobDefinition=job_definition,
        parameters={
            "bucket_name": seq_bucket_name,
            "key1": fp,
            "key2": fp.replace("R1", "R2"),
            "size": size,
            "ksize": "15",
            "outbucket": "phoenixlogan-sketches",
            "sketch_size": '100000000'
        }
    )
    prefix = sample.replace(".fastq.gz", "")
    with open(f"logs/jobs/{prefix}.json", "w") as f:
        json.dump(response, f, indent=4, default=str)
# Out:
# CMS_001_RNA_A_S1_10000000_seqbot
# CMS_002_RNA_A_S1_10000000_seqbot
# CMS_003_RNA_A_S2_10000000_seqbot
# CMS_004_RNA_A_S2_10000000_seqbot
# CMS_005_RNA_A_S3_10000000_seqbot
# CMS_006_RNA_A_S5_10000000_seqbot
# CMS_007_RNA_A_S12_10000000_seqbot
# CMS_008_RNA_A_S3_10000000_seqbot
# CMS_009_RNA_A_S13_10000000_seqbot
# CMS_010_RNA_A_S1_10000000_seqbot
# CMS_011_RNA_A_S4_10000000_seqbot
# CMS_012_RNA_A_S4_10000000_seqbot
# CMS_013_RNA_A_S5_10000000_seqbot
# CMS_014_RNA_A_S5_10000000_seqbot
# CMS_015_RNA_A_S13_10000000_seqbot
# CMS_016_RNA_A_S6_10000000_seqbot
# CMS_017_RNA_A_S6_10000000_seqbot
# CMS_018_RNA_A_S14_10000000_seqbot
# CMS_019_RNA_A_S14_10000000_seqbot
# CMS_020_RNA_A_S15_10000000_seqbot
# CMS_021_RNA_A_S16_10000000_seqbot
# CMS_022_RNA_A_S6_10000000_seqbot
# CMS_023_RNA_A_S17_10000000_seqbot
# CMS_024_RNA_A_S15_10000000_seqbot
# CMS_025_RNA_A_S7_10000000_seqbot
# CMS_026_RNA_A_S18_10000000_seqbot
# CMS_027_RNA_A_S16_10000000_seqbot
# CMS_028_RNA_A_S17_10000000_seqbot
# CMS_029_RNA_A_S18_10000000_seqbot
# CMS_030_RNA_A_S7_10000000_seqbot
# CMS_031_RNA_A_S19_10000000_seqbot
# CMS_032_RNA_A_S7_10000000_seqbot
# CMS_033_RNA_A_S8_10000000_seqbot
# CMS_034_RNA_A_S19_10000000_seqbot
# CMS_035_RNA_A_S20_10000000_seqbot
# CMS_036_RNA_A_S20_10000000_seqbot
# CMS_037_RNA_A_S21_10000000_seqbot
# CMS_038_RNA_A_S22_10000000_seqbot
# CMS_039_RNA_A_S9_10000000_seqbot
# CMS_040_RNA_A_S21_10000000_seqbot
# CMS_041_RNA_A_S10_10000000_seqbot
# CMS_042_RNA_A_S23_10000000_seqbot
# CMS_043_RNA_A_S24_10000000_seqbot
# CMS_044_RNA_A_S25_10000000_seqbot
# CMS_045_RNA_A_S2_10000000_seqbot
# CMS_046_RNA_A_S3_10000000_seqbot
# CMS_047_RNA_A_S4_10000000_seqbot
# CMS_048_RNA_A_S5_10000000_seqbot
# CMS_049_RNA_A_S6_10000000_seqbot
# CMS_050_RNA_A_S23_10000000_seqbot
# CMS_051_RNA_A_S8_10000000_seqbot
# CMS_052_RNA_A_S7_10000000_seqbot
# CMS_053_RNA_A_S8_10000000_seqbot
# CMS_054_RNA_A_S11_10000000_seqbot
# CMS_055_RNA_A_S9_10000000_seqbot
# CMS_056_RNA_A_S10_10000000_seqbot
# CMS_057_RNA_A_S11_10000000_seqbot
# CMS_058_RNA_A_S9_10000000_seqbot
# CMS_059_RNA_A_S10_10000000_seqbot
# CMS_060_RNA_A_S12_10000000_seqbot
# CMS_water1_S11_10000000_seqbot
# CMS_water2_S24_10000000_seqbot
# CMS_water3_Qiagen_S26_10000000_seqbot
# CMS_water4_Zymo_S27_10000000_seqbot
# CMS_water5_RNA_A_S12_10000000_seqbot
# CMS_002_1a_Rb_S116_L004_10000000_seqbot
# CMS_002_4a_Rb_S117_L004_10000000_seqbot
# CMS_002_7a_Rb_S118_L004_10000000_seqbot
# CMS_002_10a_Rb_S119_L004_10000000_seqbot
# CMS_002_13a_Rb_S120_L004_10000000_seqbot
# CMS_002_16a_Rb_S121_L004_10000000_seqbot
# CMS_002_17a_Rb_S122_L004_10000000_seqbot
# CMS_002_17b_Rb_S123_L004_10000000_seqbot
# CMS_002_17c_Rb_S124_L004_10000000_seqbot
# CMS_002_17d_Rb_S125_L004_10000000_seqbot
# CMS_002_17e_Rb_S126_L004_10000000_seqbot
# CMS_002_18a_Rb_S128_L004_10000000_seqbot
# CMS_002_18b_Rb_S129_L004_10000000_seqbot
# CMS_002_19a_Rb_S130_L004_10000000_seqbot
# CMS_002_20a_Rb_S131_L004_10000000_seqbot
# CMS_002_20b_Rb_S132_L004_10000000_seqbot
# CMS_002_20c_Rb_S133_L004_10000000_seqbot
# CMS_002_20d_Rb_S134_L004_10000000_seqbot
# CMS_002_20e_Rb_S135_L004_10000000_seqbot
# CMS_002_21a_Rb_S136_L004_10000000_seqbot
# CMS_002_22a_Rb_S137_L004_10000000_seqbot
# CMS_002_23a_Rb_S138_L004_10000000_seqbot
# CMS_002_25a_Rb_S140_L004_10000000_seqbot
# CMS_002_25b_Rb_S141_L004_10000000_seqbot
# CMS_002_25c_Rb_S142_L004_10000000_seqbot
# CMS_002_25d_Rb_S143_L004_10000000_seqbot
# CMS_002_25e_Rb_S144_L004_10000000_seqbot
# CMS_002_25f_Rb_S145_L004_10000000_seqbot
# CMS_002_26a_Rb_S146_L004_10000000_seqbot
# CMS_002_26b_Rb_S147_L004_10000000_seqbot
# CMS_002_26c_Rb_S148_L004_10000000_seqbot
# CMS_002_26d_Rb_S149_L004_10000000_seqbot
# CMS_002_26e_Rb_S150_L004_10000000_seqbot
# CMS_002_27a_Rb_S152_L004_10000000_seqbot
# CMS_002_27b_Rb_S153_L004_10000000_seqbot
# CMS_002_28a_Rb_S154_L004_10000000_seqbot
# CMS_002_28b_Rb_S155_L004_10000000_seqbot
# CMS_002_28c_Rb_S156_L004_10000000_seqbot
# CMS_002_28d_Rb_S157_L004_10000000_seqbot
# CMS_002_28e_Rb_S158_L004_10000000_seqbot
# CMS_002_29a_Rb_S159_L004_10000000_seqbot
# CMS_002_29b_Rb_S160_L004_10000000_seqbot
# CMS_002_29c_Rb_S161_L004_10000000_seqbot
# CMS_002_29d_Rb_S162_L004_10000000_seqbot
# CMS_002_29e_Rb_S164_L004_10000000_seqbot
# CMS_002_31a_Rb_S165_L004_10000000_seqbot
# CMS_002_32a_Rb_S166_L004_10000000_seqbot
# CMS_002_33a_Rb_S167_L004_10000000_seqbot
# CMS_002_34a_Rb_S168_L004_10000000_seqbot
# CMS_002_35a_Rb_S169_L004_10000000_seqbot
# CMS_002_36a_Rb_S170_L004_10000000_seqbot
# CMS_002_37a_Rb_S171_L004_10000000_seqbot
# CMS_002_38a_Rb_S172_L004_10000000_seqbot
# CMS_002_39a_Rb_S173_L004_10000000_seqbot
# CMS_002_40a_Rb_S174_L004_10000000_seqbot
# CMS_002_41a_Rb_S176_L004_10000000_seqbot
# CMS_002_42a_Rb_S177_L004_10000000_seqbot
# CMS_002_44a_Rb_S178_L004_10000000_seqbot
# CMS_002_44b_Rb_S179_L004_10000000_seqbot
# CMS_002_44c_Rb_S180_L004_10000000_seqbot
# CMS_002_44d_Rb_S181_L004_10000000_seqbot
# CMS_002_44e_Rb_S182_L004_10000000_seqbot
# CMS_002_45a_Rb_S183_L004_10000000_seqbot
# CMS_002_45b_Rb_S184_L004_10000000_seqbot
# CMS_002_45c_Rb_S185_L004_10000000_seqbot
# CMS_002_45d_Rb_S186_L004_10000000_seqbot
# CMS_002_45e_Rb_S188_L004_10000000_seqbot
# CMS_002_45f_Rb_S189_L004_10000000_seqbot
# CMS_002_45g_Rb_S190_L004_10000000_seqbot
# CMS_002_46a_Rb_S191_L004_10000000_seqbot
# CMS_002_46b_Rb_S192_L004_10000000_seqbot
# CMS_002_47a_Rb_S193_L004_10000000_seqbot
# CMS_002_47b_Rb_S194_L004_10000000_seqbot
# CMS_002_47c_Rb_S195_L004_10000000_seqbot
# CMS_002_47d_Rb_S196_L004_10000000_seqbot
# CMS_002_47e_Rb_S197_L004_10000000_seqbot
# CMS_002_47f_Rb_S198_L004_10000000_seqbot
# CMS_002_47g_Rb_S200_L004_10000000_seqbot
# CMS_002_47h_Rb_S1_L004_10000000_seqbot
# CMS_002_47i_Rb_S2_L004_10000000_seqbot
# CMS_002_47j_Rb_S3_L004_10000000_seqbot
# CMS_002_49a_Rb_S4_L004_10000000_seqbot
# CMS_002_50a_Rb_S5_L004_10000000_seqbot
# CMS_002_51a_Rb_S6_L004_10000000_seqbot
# CMS_002_53a_Rb_S7_L004_10000000_seqbot
# CMS_002_54a_Rb_S8_L004_10000000_seqbot
# CMS_002_56a_Rb_S9_L004_10000000_seqbot
# CMS_002_57a_Rb_S10_L004_10000000_seqbot
# CMS_002_Water1_Rb_S127_L004_10000000_seqbot
# CMS_002_Water2_Rb_S139_L004_10000000_seqbot
# CMS_002_Water3_Rb_S151_L004_10000000_seqbot
# CMS_002_Water4_Rb_S163_L004_10000000_seqbot
# CMS_002_Water5_Rb_S175_L004_10000000_seqbot
# CMS_002_Water6_Rb_S187_L004_10000000_seqbot
# CMS_002_Water7_Rb_S199_L004_10000000_seqbot
# CMS_002_Water8_Rb_S11_L004_10000000_seqbot

# %%
# submit batch jobs 

seq_bucket_name = "czbiohub-mosquito"

for fp in all_file_paths:
    sample = os.path.basename(fp).replace('.fastq.gz', '')
    size = "10000000_csv"
    identifier = f"{sample}_{size}"
    print(identifier)
    response = batch_client.submit_job(
        jobName=identifier,
        jobQueue=job_queue,
        jobDefinition=job_definition,
        parameters={
            "bucket_name": seq_bucket_name,
            "key1": fp,
            "key2": fp.replace("R1", "R2"),
            "size": size,
            "ksize": "15",
            "outbucket": "phoenixlogan-sketches",
            "sketch_size": '100000000'
        }
    )
    prefix = sample.replace(".fastq.gz", "")
    with open(f"logs/jobs/{prefix}.json", "w") as f:
        json.dump(response, f, indent=4, default=str)
# Out:
# CMS_001_RNA_A_S1_R1_001_10000000
# CMS_002_RNA_A_S1_R1_001_10000000
# CMS_003_RNA_A_S2_R1_001_10000000
# CMS_004_RNA_A_S2_R1_001_10000000
# CMS_005_RNA_A_S3_R1_001_10000000
# CMS_006_RNA_A_S5_R1_001_10000000
# CMS_007_RNA_A_S12_R1_001_10000000
# CMS_008_RNA_A_S3_R1_001_10000000
# CMS_009_RNA_A_S13_R1_001_10000000
# CMS_010_RNA_A_S1_R1_001_10000000
# CMS_011_RNA_A_S4_R1_001_10000000
# CMS_012_RNA_A_S4_R1_001_10000000
# CMS_013_RNA_A_S5_R1_001_10000000
# CMS_014_RNA_A_S5_R1_001_10000000
# CMS_015_RNA_A_S13_R1_001_10000000
# CMS_016_RNA_A_S6_R1_001_10000000
# CMS_017_RNA_A_S6_R1_001_10000000
# CMS_018_RNA_A_S14_R1_001_10000000
# CMS_019_RNA_A_S14_R1_001_10000000
# CMS_020_RNA_A_S15_R1_001_10000000
# CMS_021_RNA_A_S16_R1_001_10000000
# CMS_022_RNA_A_S6_R1_001_10000000
# CMS_023_RNA_A_S17_R1_001_10000000
# CMS_024_RNA_A_S15_R1_001_10000000
# CMS_025_RNA_A_S7_R1_001_10000000
# CMS_026_RNA_A_S18_R1_001_10000000
# CMS_027_RNA_A_S16_R1_001_10000000
# CMS_028_RNA_A_S17_R1_001_10000000
# CMS_029_RNA_A_S18_R1_001_10000000
# CMS_030_RNA_A_S7_R1_001_10000000
# CMS_031_RNA_A_S19_R1_001_10000000
# CMS_032_RNA_A_S7_R1_001_10000000
# CMS_033_RNA_A_S8_R1_001_10000000
# CMS_034_RNA_A_S19_R1_001_10000000
# CMS_035_RNA_A_S20_R1_001_10000000
# CMS_036_RNA_A_S20_R1_001_10000000
# CMS_037_RNA_A_S21_R1_001_10000000
# CMS_038_RNA_A_S22_R1_001_10000000
# CMS_039_RNA_A_S9_R1_001_10000000
# CMS_040_RNA_A_S21_R1_001_10000000
# CMS_041_RNA_A_S10_R1_001_10000000
# CMS_042_RNA_A_S23_R1_001_10000000
# CMS_043_RNA_A_S24_R1_001_10000000
# CMS_044_RNA_A_S25_R1_001_10000000
# CMS_045_RNA_A_S2_R1_001_10000000
# CMS_046_RNA_A_S3_R1_001_10000000
# CMS_047_RNA_A_S4_R1_001_10000000
# CMS_048_RNA_A_S5_R1_001_10000000
# CMS_049_RNA_A_S6_R1_001_10000000
# CMS_050_RNA_A_S23_R1_001_10000000
# CMS_051_RNA_A_S8_R1_001_10000000
# CMS_052_RNA_A_S7_R1_001_10000000
# CMS_053_RNA_A_S8_R1_001_10000000
# CMS_054_RNA_A_S11_R1_001_10000000
# CMS_055_RNA_A_S9_R1_001_10000000
# CMS_056_RNA_A_S10_R1_001_10000000
# CMS_057_RNA_A_S11_R1_001_10000000
# CMS_058_RNA_A_S9_R1_001_10000000
# CMS_059_RNA_A_S10_R1_001_10000000
# CMS_060_RNA_A_S12_R1_001_10000000
# CMS_water1_S11_R1_001_10000000
# CMS_water2_S24_R1_001_10000000
# CMS_water3_Qiagen_S26_R1_001_10000000
# CMS_water4_Zymo_S27_R1_001_10000000
# CMS_water5_RNA_A_S12_R1_001_10000000
# CMS_002_10a_Rb_S119_L004_R1_001_10000000
# CMS_002_13a_Rb_S120_L004_R1_001_10000000
# CMS_002_16a_Rb_S121_L004_R1_001_10000000
# CMS_002_17a_Rb_S122_L004_R1_001_10000000
# CMS_002_17b_Rb_S123_L004_R1_001_10000000
# CMS_002_17c_Rb_S124_L004_R1_001_10000000
# CMS_002_17d_Rb_S125_L004_R1_001_10000000
# CMS_002_17e_Rb_S126_L004_R1_001_10000000
# CMS_002_18a_Rb_S128_L004_R1_001_10000000
# CMS_002_18b_Rb_S129_L004_R1_001_10000000
# CMS_002_19a_Rb_S130_L004_R1_001_10000000
# CMS_002_1a_Rb_S116_L004_R1_001_10000000
# CMS_002_20a_Rb_S131_L004_R1_001_10000000
# CMS_002_20b_Rb_S132_L004_R1_001_10000000
# CMS_002_20c_Rb_S133_L004_R1_001_10000000
# CMS_002_20d_Rb_S134_L004_R1_001_10000000
# CMS_002_20e_Rb_S135_L004_R1_001_10000000
# CMS_002_21a_Rb_S136_L004_R1_001_10000000
# CMS_002_22a_Rb_S137_L004_R1_001_10000000
# CMS_002_23a_Rb_S138_L004_R1_001_10000000
# CMS_002_25a_Rb_S140_L004_R1_001_10000000
# CMS_002_25b_Rb_S141_L004_R1_001_10000000
# CMS_002_25c_Rb_S142_L004_R1_001_10000000
# CMS_002_25d_Rb_S143_L004_R1_001_10000000
# CMS_002_25e_Rb_S144_L004_R1_001_10000000
# CMS_002_25f_Rb_S145_L004_R1_001_10000000
# CMS_002_26a_Rb_S146_L004_R1_001_10000000
# CMS_002_26b_Rb_S147_L004_R1_001_10000000
# CMS_002_26c_Rb_S148_L004_R1_001_10000000
# CMS_002_26d_Rb_S149_L004_R1_001_10000000
# CMS_002_26e_Rb_S150_L004_R1_001_10000000
# CMS_002_27a_Rb_S152_L004_R1_001_10000000
# CMS_002_27b_Rb_S153_L004_R1_001_10000000
# CMS_002_28a_Rb_S154_L004_R1_001_10000000
# CMS_002_28b_Rb_S155_L004_R1_001_10000000
# CMS_002_28c_Rb_S156_L004_R1_001_10000000
# CMS_002_28d_Rb_S157_L004_R1_001_10000000
# CMS_002_28e_Rb_S158_L004_R1_001_10000000
# CMS_002_29a_Rb_S159_L004_R1_001_10000000
# CMS_002_29b_Rb_S160_L004_R1_001_10000000
# CMS_002_29c_Rb_S161_L004_R1_001_10000000
# CMS_002_29d_Rb_S162_L004_R1_001_10000000
# CMS_002_29e_Rb_S164_L004_R1_001_10000000
# CMS_002_31a_Rb_S165_L004_R1_001_10000000
# CMS_002_32a_Rb_S166_L004_R1_001_10000000
# CMS_002_33a_Rb_S167_L004_R1_001_10000000
# CMS_002_34a_Rb_S168_L004_R1_001_10000000
# CMS_002_35a_Rb_S169_L004_R1_001_10000000
# CMS_002_36a_Rb_S170_L004_R1_001_10000000
# CMS_002_37a_Rb_S171_L004_R1_001_10000000
# CMS_002_38a_Rb_S172_L004_R1_001_10000000
# CMS_002_39a_Rb_S173_L004_R1_001_10000000
# CMS_002_40a_Rb_S174_L004_R1_001_10000000
# CMS_002_41a_Rb_S176_L004_R1_001_10000000
# CMS_002_42a_Rb_S177_L004_R1_001_10000000
# CMS_002_44a_Rb_S178_L004_R1_001_10000000
# CMS_002_44b_Rb_S179_L004_R1_001_10000000
# CMS_002_44c_Rb_S180_L004_R1_001_10000000
# CMS_002_44d_Rb_S181_L004_R1_001_10000000
# CMS_002_44e_Rb_S182_L004_R1_001_10000000
# CMS_002_45a_Rb_S183_L004_R1_001_10000000
# CMS_002_45b_Rb_S184_L004_R1_001_10000000
# CMS_002_45c_Rb_S185_L004_R1_001_10000000
# CMS_002_45d_Rb_S186_L004_R1_001_10000000
# CMS_002_45e_Rb_S188_L004_R1_001_10000000
# CMS_002_45f_Rb_S189_L004_R1_001_10000000
# CMS_002_45g_Rb_S190_L004_R1_001_10000000
# CMS_002_46a_Rb_S191_L004_R1_001_10000000
# CMS_002_46b_Rb_S192_L004_R1_001_10000000
# CMS_002_47a_Rb_S193_L004_R1_001_10000000
# CMS_002_47b_Rb_S194_L004_R1_001_10000000
# CMS_002_47c_Rb_S195_L004_R1_001_10000000
# CMS_002_47d_Rb_S196_L004_R1_001_10000000
# CMS_002_47e_Rb_S197_L004_R1_001_10000000
# CMS_002_47f_Rb_S198_L004_R1_001_10000000

# %%
all_file_paths
# Out:
# ['sequences/CMS001_fastq.gz/CMS_001_RNA_A_S1_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_002_RNA_A_S1_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_003_RNA_A_S2_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_004_RNA_A_S2_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_005_RNA_A_S3_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_006_RNA_A_S5_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_007_RNA_A_S12_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_008_RNA_A_S3_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_009_RNA_A_S13_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_010_RNA_A_S1_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_011_RNA_A_S4_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_012_RNA_A_S4_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_013_RNA_A_S5_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_014_RNA_A_S5_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_015_RNA_A_S13_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_016_RNA_A_S6_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_017_RNA_A_S6_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_018_RNA_A_S14_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_019_RNA_A_S14_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_020_RNA_A_S15_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_021_RNA_A_S16_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_022_RNA_A_S6_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_023_RNA_A_S17_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_024_RNA_A_S15_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_025_RNA_A_S7_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_026_RNA_A_S18_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_027_RNA_A_S16_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_028_RNA_A_S17_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_029_RNA_A_S18_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_030_RNA_A_S7_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_031_RNA_A_S19_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_032_RNA_A_S7_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_033_RNA_A_S8_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_034_RNA_A_S19_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_035_RNA_A_S20_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_036_RNA_A_S20_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_037_RNA_A_S21_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_038_RNA_A_S22_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_039_RNA_A_S9_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_040_RNA_A_S21_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_041_RNA_A_S10_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_042_RNA_A_S23_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_043_RNA_A_S24_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_044_RNA_A_S25_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_045_RNA_A_S2_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_046_RNA_A_S3_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_047_RNA_A_S4_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_048_RNA_A_S5_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_049_RNA_A_S6_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_050_RNA_A_S23_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_051_RNA_A_S8_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_052_RNA_A_S7_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_053_RNA_A_S8_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_054_RNA_A_S11_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_055_RNA_A_S9_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_056_RNA_A_S10_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_057_RNA_A_S11_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_058_RNA_A_S9_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_059_RNA_A_S10_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_060_RNA_A_S12_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_water1_S11_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_water2_S24_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_water3_Qiagen_S26_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_water4_Zymo_S27_R1_001.fastq.gz',
#  'sequences/CMS001_fastq.gz/CMS_water5_RNA_A_S12_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_10a_Rb_S119_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_13a_Rb_S120_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_16a_Rb_S121_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_17a_Rb_S122_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_17b_Rb_S123_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_17c_Rb_S124_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_17d_Rb_S125_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_17e_Rb_S126_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_18a_Rb_S128_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_18b_Rb_S129_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_19a_Rb_S130_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_1a_Rb_S116_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_20a_Rb_S131_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_20b_Rb_S132_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_20c_Rb_S133_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_20d_Rb_S134_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_20e_Rb_S135_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_21a_Rb_S136_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_22a_Rb_S137_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_23a_Rb_S138_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_25a_Rb_S140_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_25b_Rb_S141_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_25c_Rb_S142_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_25d_Rb_S143_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_25e_Rb_S144_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_25f_Rb_S145_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_26a_Rb_S146_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_26b_Rb_S147_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_26c_Rb_S148_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_26d_Rb_S149_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_26e_Rb_S150_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_27a_Rb_S152_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_27b_Rb_S153_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_28a_Rb_S154_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_28b_Rb_S155_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_28c_Rb_S156_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_28d_Rb_S157_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_28e_Rb_S158_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_29a_Rb_S159_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_29b_Rb_S160_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_29c_Rb_S161_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_29d_Rb_S162_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_29e_Rb_S164_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_31a_Rb_S165_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_32a_Rb_S166_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_33a_Rb_S167_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_34a_Rb_S168_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_35a_Rb_S169_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_36a_Rb_S170_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_37a_Rb_S171_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_38a_Rb_S172_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_39a_Rb_S173_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_40a_Rb_S174_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_41a_Rb_S176_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_42a_Rb_S177_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_44a_Rb_S178_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_44b_Rb_S179_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_44c_Rb_S180_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_44d_Rb_S181_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_44e_Rb_S182_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_45a_Rb_S183_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_45b_Rb_S184_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_45c_Rb_S185_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_45d_Rb_S186_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_45e_Rb_S188_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_45f_Rb_S189_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_45g_Rb_S190_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_46a_Rb_S191_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_46b_Rb_S192_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_47a_Rb_S193_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_47b_Rb_S194_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_47c_Rb_S195_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_47d_Rb_S196_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_47e_Rb_S197_L004_R1_001.fastq.gz',
#  'sequences/CMS002_fastq.gz/CMS_002_47f_Rb_S198_L004_R1_001.fastq.gz']

# %%
fp = all_file_paths[0]

# %%
len(all_file_paths)
# Out:
# 140

# %%
os.path.basename(fp).replace('.fastq.gz', '')
# Out:
# 'CMS_001_RNA_A_S1_R1_001'

# %%
all_file_paths[0]
# Out:
# 'sequences/CMS001_fastq.gz/CMS_001_RNA_A_S1_R1_001.fastq.gz'
